# %%
import pandas as pd

data = {
    "Date": [
        "2024-01-01","2024-01-05","2024-01-10",
        "2024-02-01","2024-02-07","2024-02-15",
        "2024-03-01","2024-03-10"
    ],
    "Region": ["North","South","East","West","North","South","East","West"],
    "Product": ["Laptop","Mobile","Tablet","Laptop","Mobile","Tablet","Laptop","Mobile"],
    "Sales": [50000,30000,20000,55000,32000,25000,60000,35000]
}

df = pd.DataFrame(data)
df.to_csv("sales.csv", index=False)

print("sales.csv created successfully")
# Out:
# sales.csv created successfully

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("sales.csv")
df['Date'] = pd.to_datetime(df['Date'])

print("Sales Data:")
print(df)

# -------------------------------
# 1. Region-wise Sales Analysis
# -------------------------------
region_sales = df.groupby('Region')['Sales'].sum()
print("\nRegion-wise Sales:")
print(region_sales)

plt.figure()
region_sales.plot(kind='bar')
plt.title("Region-wise Sales")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.show()

# -------------------------------
# 2. Product-wise Sales Analysis
# -------------------------------
product_sales = df.groupby('Product')['Sales'].sum()
print("\nProduct-wise Sales:")
print(product_sales)

plt.figure()
product_sales.plot(kind='pie', autopct='%1.1f%%')
plt.title("Product-wise Sales Distribution")
plt.ylabel("")
plt.show()

# -------------------------------
# 3. Monthly Sales Trend
# -------------------------------
df['Month'] = df['Date'].dt.to_period('M')
monthly_sales = df.groupby('Month')['Sales'].sum()

print("\nMonthly Sales Trend:")
print(monthly_sales)

plt.figure()
monthly_sales.plot(kind='line', marker='o')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# -------------------------------
# Save Output
# -------------------------------
df.to_csv("sales_analysis_results.csv", index=False)
print("\nAnalysis complete. Results saved to sales_analysis_results.csv")
# Out:
# Sales Data:
#         Date Region Product  Sales
# 0 2024-01-01  North  Laptop  50000
# 1 2024-01-05  South  Mobile  30000
# 2 2024-01-10   East  Tablet  20000
# 3 2024-02-01   West  Laptop  55000
# 4 2024-02-07  North  Mobile  32000
# 5 2024-02-15  South  Tablet  25000
# 6 2024-03-01   East  Laptop  60000
# 7 2024-03-10   West  Mobile  35000
#
# Region-wise Sales:
# Region
# East     80000
# North    82000
# South    55000
# West     90000
# Name: Sales, dtype: int64
# Product-wise Sales:
# Product
# Laptop    165000
# Mobile     97000
# Tablet     45000
# Name: Sales, dtype: int64
# Monthly Sales Trend:
# Month
# 2024-01    100000
# 2024-02    112000
# 2024-03     95000
# Freq: M, Name: Sales, dtype: int64
# Analysis complete. Results saved to sales_analysis_results.csv
